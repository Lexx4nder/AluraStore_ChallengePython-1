# %% [markdown]
# <a href="https://colab.research.google.com/github/Lexx4nder/AluraStore_ChallengePython-1/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# 1  Tarjeta de crédito                   4   6.25184 -75.56359
# 2  Tarjeta de crédito                   1  10.39972 -75.51444
# 3               Nequi                   1   3.43722 -76.52250
# 4               Nequi                   1   6.25184 -75.56359

# %% [markdown]
# #1. Análisis de facturación

# %%
ingreso_tienda_1 = tienda['Precio'].sum()
print("\nIngreso Total Tienda 1:",ingreso_tienda_1)
ingreso_tienda_2 = tienda2['Precio'].sum()
print("\nIngreso Total Tienda 2:",ingreso_tienda_2)
ingreso_tienda_3 = tienda3['Precio'].sum()
print("\nIngreso Total Tienda 3:",ingreso_tienda_3)
ingreso_tienda_4 = tienda4['Precio'].sum()
print("\nIngreso Total Tienda 4:",ingreso_tienda_4)
# Out:
# Ingreso Total Tienda 1: 1150880400.0
#
# Ingreso Total Tienda 2: 1116343500.0
#
# Ingreso Total Tienda 3: 1098019600.0
#
# Ingreso Total Tienda 4: 1038375700.0

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

ingresos = [ingreso_tienda_1, ingreso_tienda_2, ingreso_tienda_3, ingreso_tienda_4]
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']

def formatear_y(valor, _):
    return f"${valor:,.0f}"

fig, ax = plt.subplots(figsize=(10, 8))  # Más espacio vertical
ax.bar(tiendas, ingresos, color='blue')
ax.yaxis.set_major_formatter(FuncFormatter(formatear_y))

plt.title("Ingresos Totales por Tienda")
plt.ylabel("Ingresos ($)")
plt.xlabel("Tiendas")

plt.tight_layout()

# %% [markdown]
# # 2. Ventas por categoría

# %%
categorias_tienda_1 = tienda['Categoría del Producto'].value_counts()
print("\nTienda 1 - Categorías más vendidas:\n", categorias_tienda_1.head(3))
categorias_tienda_2 = tienda2['Categoría del Producto'].value_counts()
print("\nTienda 2 - Categorías más vendidas:\n", categorias_tienda_2.head(3))
categorias_tienda_3 = tienda3['Categoría del Producto'].value_counts()
print("\nTienda 3 - Categorías más vendidas:\n", categorias_tienda_3.head(3))
categorias_tienda_4 = tienda4['Categoría del Producto'].value_counts()
print("\nTienda 4 - Categorías más vendidas:\n", categorias_tienda_4.head(3))
# Out:
# Tienda 1 - Categorías más vendidas:
#  Categoría del Producto
# Muebles         465
# Electrónicos    448
# Juguetes        324
# Name: count, dtype: int64
#
# Tienda 2 - Categorías más vendidas:
#  Categoría del Producto
# Muebles         442
# Electrónicos    422
# Juguetes        313
# Name: count, dtype: int64
#
# Tienda 3 - Categorías más vendidas:
#  Categoría del Producto
# Muebles         499
# Electrónicos    451
# Juguetes        315
# Name: count, dtype: int64
#
# Tienda 4 - Categorías más vendidas:
#  Categoría del Producto
# Muebles         480
# Electrónicos    451
# Juguetes        338
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos por categoría (valores absolutos)
categorias = ['Muebles', 'Electrónicos', 'Juguetes']
tienda_1 = [465, 448, 324]
tienda_2 = [442, 422, 313]
tienda_3 = [499, 451, 315]
tienda_4 = [480, 451, 338]

# Preparar posición de barras
x = np.arange(len(categorias))
width = 0.2

# Crear gráfico
plt.figure(figsize=(10, 6))
plt.bar(x - 1.5 * width, tienda_1, width, label='Tienda 1', color='green')
plt.bar(x - 0.5 * width, tienda_2, width, label='Tienda 2', color='red')  # Menor desempeño
plt.bar(x + 0.5 * width, tienda_3, width, label='Tienda 3', color='darkblue')
plt.bar(x + 1.5 * width, tienda_4, width, label='Tienda 4', color='skyblue')

# Personalización
plt.title("Comparación de Categorías Más Vendidas por Tienda")
plt.ylabel("Cantidad de Productos Vendidos")
plt.xticks(x, categorias)
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
calificacion_tienda_1 = tienda['Calificación'].mean()
print("\nTienda 1 - Calificación:\n", round(calificacion_tienda_1,2))
calificacion_tienda_2 = tienda2['Calificación'].mean()
print("\nTienda 2 - Calificación:\n", round(calificacion_tienda_2,2))
calificacion_tienda_3 = tienda3['Calificación'].mean()
print("\nTienda 3 - Calificación:\n", round(calificacion_tienda_3,2))
calificacion_tienda_4 = tienda4['Calificación'].mean()
print("\nTienda 4 - Calificación:\n", round(calificacion_tienda_4,2))
# Out:
# Tienda 1 - Calificación:
#  3.98
#
# Tienda 2 - Calificación:
#  4.04
#
# Tienda 3 - Calificación:
#  4.05
#
# Tienda 4 - Calificación:
#  4.0

# %%
# Datos
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
calificaciones = [
    round(calificacion_tienda_1, 2),
    round(calificacion_tienda_2, 2),
    round(calificacion_tienda_3, 2),
    round(calificacion_tienda_4, 2)
]

# Crear gráfico
plt.figure(figsize=(8, 5))
plt.bar(tiendas, calificaciones, color='purple', edgecolor='black')

# Agregar texto encima de cada barra
for i, valor in enumerate(calificaciones):
    plt.text(i, valor + 0.05, str(valor), ha='center', fontsize=10)

# Personalización
plt.title("Calificación Promedio por Tienda")
plt.xlabel("Tiendas")
plt.ylabel("Calificación (1–5)")
plt.ylim(0, 5)
plt.grid(axis='y', linestyle='--', alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
producto_tienda_1 = tienda['Producto'].value_counts()
print("\nMás vendido T1 -",producto_tienda_1.idxmax(),"  #  ",producto_tienda_1.max())
print("Menos vendido T1 -",producto_tienda_1.idxmin(),"  #  ",producto_tienda_1.min())
producto_tienda_2 = tienda2['Producto'].value_counts()
print("\nMás vendido T2 -",producto_tienda_2.idxmax(),"  #  ",producto_tienda_2.max())
print("Menos vendido T2 -",producto_tienda_2.idxmin(),"  #  ",producto_tienda_2.min())
producto_tienda_3 = tienda3['Producto'].value_counts()
print("\nMás vendido T3 -",producto_tienda_3.idxmax(),"  #  ",producto_tienda_3.max())
print("Menos vendido T3 -",producto_tienda_3.idxmin(),"  #  ",producto_tienda_3.min())
producto_tienda_4 = tienda4['Producto'].value_counts()
print("\nMás vendido T4 -",producto_tienda_4.idxmax(),"  #  ",producto_tienda_4.max())
print("Menos vendido T4 -",producto_tienda_4.idxmin(),"  #  ",producto_tienda_4.min())
# Out:
# Más vendido T1 - Microondas   #   60
# Menos vendido T1 - Auriculares con micrófono   #   33
#
# Más vendido T2 - Iniciando en programación   #   65
# Menos vendido T2 - Juego de mesa   #   32
#
# Más vendido T3 - Kit de bancas   #   57
# Menos vendido T3 - Bloques de construcción   #   35
#
# Más vendido T4 - Cama box   #   62
# Menos vendido T4 - Guitarra eléctrica   #   33

# %%
import matplotlib.pyplot as plt

# Nombres de productos más y menos vendidos
productos_mas = [
    producto_tienda_1.idxmax(),
    producto_tienda_2.idxmax(),
    producto_tienda_3.idxmax(),
    producto_tienda_4.idxmax()
]

ventas_mas = [
    producto_tienda_1.max(),
    producto_tienda_2.max(),
    producto_tienda_3.max(),
    producto_tienda_4.max()
]

productos_menos = [
    producto_tienda_1.idxmin(),
    producto_tienda_2.idxmin(),
    producto_tienda_3.idxmin(),
    producto_tienda_4.idxmin()
]

ventas_menos = [
    producto_tienda_1.min(),
    producto_tienda_2.min(),
    producto_tienda_3.min(),
    producto_tienda_4.min()
]

tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']

# Configurar gráfico
fig, ax = plt.subplots(figsize=(10, 6))
bar_width = 0.4
x = range(len(tiendas))

# Barras para más vendidos
ax.bar(x, ventas_mas, width=bar_width, label='Más Vendido', color='green')

# Barras para menos vendidos (desplazadas)
ax.bar([i + bar_width for i in x], ventas_menos, width=bar_width, label='Menos Vendido', color='red')

# Etiquetas y títulos
ax.set_xticks([i + bar_width / 2 for i in x])
ax.set_xticklabels(tiendas)
ax.set_ylabel('Número de Ventas')
ax.set_title('Productos Más y Menos Vendidos por Tienda')
ax.legend()

# Mostrar nombres de productos como etiquetas encima de cada barra
for i in range(len(tiendas)):
    ax.text(x[i], ventas_mas[i] + 0.5, productos_mas[i], ha='center', va='bottom', fontsize=9, rotation=45)
    ax.text(x[i] + bar_width, ventas_menos[i] + 0.5, productos_menos[i], ha='center', va='bottom', fontsize=9, rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
Envio_tienda_1 = tienda['Costo de envío'].mean()
print("\nTienda 1:\n", round(Envio_tienda_1))
Envio_tienda_2 = tienda2['Costo de envío'].mean()
print("\nTienda 2:\n", round(Envio_tienda_2))
Envio_tienda_3 = tienda3['Costo de envío'].mean()
print("\nTienda 3:\n", round(Envio_tienda_3))
Envio_tienda_4 = tienda4['Costo de envío'].mean()
print("\nTienda 4:\n", round(Envio_tienda_4))
# Out:
# Tienda 1:
#  26019
#
# Tienda 2:
#  25216
#
# Tienda 3:
#  24806
#
# Tienda 4:
#  23459

# %%
# Datos
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
envios = [
    round(Envio_tienda_1, 2),
    round(Envio_tienda_2, 2),
    round(Envio_tienda_3, 2),
    round(Envio_tienda_4, 2)
]

# Crear gráfico
plt.figure(figsize=(8, 5))
plt.barh(tiendas, envios, color='darkblue', edgecolor='black')

# Mostrar valor al final de cada barra
for i, valor in enumerate(envios):
    plt.text(valor + 0.1, i, f"${valor}", va='center', fontsize=9)

# Personalización
plt.title("Costo de Envío Promedio por Tienda")
plt.xlabel("Costo de Envío ($)")
plt.ylabel("Tiendas")
plt.xlim(0, max(envios) + 5)
plt.grid(axis='x', linestyle='--', alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
#  **INFORME FINAL AluraStore - ANALISIS DE DATOS**
#
#
#
#
#
# El presente informe tiene como objetivo el analizar el rendimiento de cuatro tiendas mediante diferentes métricas comerciales y de satisfacción del cliente.
#
#
#
# Se busca ayudar al SR. Juan a identificar qué tienda es la menos rentable para iniciar los tramites de venta.
#
#
#
# Los datos que fueron utilizados fueron los siguientes:
#
# * Los ingresos totales de las tiendas.
#
# * Las categorías de productos más y menos vendidas.
#
# * Las calificaciones promedio de los clientes por tienda.
#
# * Los productos más y menos vendidos.
#
# * El coste de envío promedio para cada tienda.
#
# Las herramientas que se emplearon fueron multiples bibliotecas de python como: pandas, matplotlib.pyplot, etc.

# %% [markdown]
# **INGRESOS TOTALES**
#
# **TIENDAS AluraStore**
#
# ![Primer grafica Ingresos totales.png](data:image/png;base64,...)
#
#
# **La tienda con MENOR ingresos fue la Tienda 4, ya que sólo reportó un total de $1,038,375,700.0 MXN en el periodo analizado versus el resto.**
#
#
# ### 💰 1. Ingresos Totales
#
# Los ingresos calculados por la suma de la columna `'Precio'` revelan el siguiente resultado:
#
# Total Tienda 1: **1,150,880,400.0**
#
#
# Total Tienda 2: **1,116,343,500.0**
#
#
# Total Tienda 3: **1,098,019,600.0**
#
#
# Total Tienda 4: **1,038,375,700.0**
#
#
# 🔎 **Tienda 4** obtuvo el ingreso más bajo, quedando por debajo de sus competidoras.

# %% [markdown]
# **CATEGORIAS DE PRODUCTOS**
#
# Tiendas AluraStore 4-1
#
# ![Categorias.png](data:image/png;base64,...)
#
# ### 🧁 2. Categorías Más Vendidas
#
# **En este analisis podemos determinar que la categoria más popular en todas las tiendas es la del area de MUEBLES**
#
# Se agruparon los productos por `'Categoría del Producto'` usando `value_counts()` para determinar la popularidad por tienda. Las tiendas 1, 3 y 4 mostraron distribución diversa y liderazgo en categorías como Electrónica y Hogar. En cambio:
#
# 🔎 **Tienda 2** presentó menor volumen de ventas en sus principales categorías y menor diversidad en comparación con las demás.
#
# ---
#
# Cabe resaltar algunos puntos importantes:
#
#
# ~La **Tienda 2** tiene un bajo desempeño en el area de Juguetes por lo que podría ser un factor a considerar ya que representa un alto porcentaje de diferencia. Implementar actividades para mitigar el impacto cómo una capacitación del personal, enfocada a identificar areas de oportunidad y sacar provecho de la demanda en la zona.
#
# ~La **Tienda 1** tiene un alto desempeño en general en las tres áreas, pudiera calificar para algun proyecto de capacitación y mejorar el porcentaje a numeros mas altos.

# %% [markdown]
# **CALIFICACIONES PROMEDIO**
#
# AluraStore Tiendas
#
# ![Calificacion por tienda.png](data:image/png;base64,...)
#
#
# ### ⭐ 4. Calificación Promedio de Clientes
#
# Se calculó el promedio de `'Calificación'` por tienda:
#
# **Tienda 1** - Calificación:
#  3.98
#
# **Tienda 2** - Calificación:
#  4.04
#
# **Tienda 3** - Calificación:
#  4.05
#
# **Tienda 4** - Calificación:
#  4.0
#
# 🔎 **Tienda 1** obtuvo la calificación más baja, lo que indica menor satisfacción de los clientes.

# %% [markdown]
# **PRODUCTOS MÁS Y MENOS VENDIDOS**
#
# AluraStore Tiendas
#
# ![Productos mas y menos vendidos.png](data:image/png;base64,...)
#
#
#
# ### 🛍️ 3. Productos Más y Menos Vendidos
#
# Al evaluar con `value_counts()` los productos más y menos vendidos por tienda:
#
#
#
# Más vendido **T1** - Microondas   #   60
# Menos vendido **T1** - Auriculares con micrófono   #   33
#
# Más vendido **T2** - Iniciando en programación   #   65
# Menos vendido **T2** - Juego de mesa   #   32
#
# Más vendido **T3** - Kit de bancas   #   57
# Menos vendido **T3** - Bloques de construcción   #   35
#
# Más vendido **T4** - Cama box   #   62
# Menos vendido **T4** - Guitarra eléctrica   #   33
#
#
#
# - Tienda 1, 2 y 4 cuentan con productos líderes en ventas con alto margen.
#
# - **Tienda 3** muestra productos menos vendidos en mayor cantidad, lo que indica baja rotación y bajo desempeño comercial.
#
# 🔎 Este patrón sugiere falta de productos atractivos en Tienda 3.
#
#
# El analisis refuerza que la categoria mejor vendida de la empresa es el area de MUEBLES y ELECTRONICOS por lo tanto es su fuerte de ingresos.

# %% [markdown]
# **COSTOS ENVIO PROMEDIO**
#
# AluraStore Tiendas
#
# ![Costo envio por tienda.png](data:image/png;base64,...)
#
#
#
# ### 🚚 5. Costo de Envío Promedio
#
# Se analizaron los costos promedio de envío por tienda (`'Costo de envío'`):
#
#
# *Tienda 1:*
#  $26019
#
# *Tienda 2:*
#  $25216
#
# *Tienda 3:*
#  $24806
#
# *Tienda 4:*
#  $23459
#
#
# 🔎 **Tienda 1** tiene el mayor costo de envío, afectando la rentabilidad general.

# %% [markdown]
# ## 📌 Conclusión y Recomendación
#
# Luego de comparar todas las métricas clave, **Tienda 2** presenta consistentemente los peores resultados:
#
# * Tiene los ingresos más bajos.
#
# * Muestra poca diversidad en categorías, lo que limita el alcance comercial.
#
# * Su costo de envío es el segundo más alto. Tiene una calificación razonable,
# no sobresale en ninguna métrica clave.
#
# * Su desempeño general se mantiene estable pero inferior comparado al resto.
#
#
#
#
# 📌 Recomendación Final: El Sr. Juan debería considerar vender la **Tienda 2**, ya que es la menos rentable y no destaca en ninguna categoría analizada, lo que representa una oportunidad limitada de mejora frente a las demás. Considerando que son aspectos de mejora más volátiles, sin alta probabilidad de éxito.
#
# Esta decisión está respaldada por datos objetivos, y permitirá al Sr. Juan enfocar recursos en tiendas más rentables y con mayor potencial de crecimiento.
#
#
# ---
#
# **Fin del informe.**
